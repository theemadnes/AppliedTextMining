# %% [markdown]
# ---
#
# _You are currently looking at **version 1.0** of this notebook. To download notebooks and datafiles, as well as get help on Jupyter notebooks in the Coursera platform, visit the [Jupyter Notebook FAQ](https://www.coursera.org/learn/python-text-mining/resources/d9pwm) course resource._
#
# ---

# %% [markdown]
# # Assignment 1
#
# In this assignment, you'll be working with messy medical data and using regex to extract relevant infromation from the data.
#
# Each line of the `dates.txt` file corresponds to a medical note. Each note has a date that needs to be extracted, but each date is encoded in one of many formats.
#
# The goal of this assignment is to correctly identify all of the different date variants encoded in this dataset and to properly normalize and sort the dates.
#
# Here is a list of some of the variants you might encounter in this dataset:
# * 04/20/2009; 04/20/09; 4/20/09; 4/3/09
# * Mar-20-2009; Mar 20, 2009; March 20, 2009;  Mar. 20, 2009; Mar 20 2009;
# * 20 Mar 2009; 20 March 2009; 20 Mar. 2009; 20 March, 2009
# * Mar 20th, 2009; Mar 21st, 2009; Mar 22nd, 2009
# * Feb 2009; Sep 2009; Oct 2010
# * 6/2008; 12/2009
# * 2009; 2010
#
# Once you have extracted these date patterns from the text, the next step is to sort them in ascending chronological order accoring to the following rules:
# * Assume all dates in xx/xx/xx format are mm/dd/yy
# * Assume all dates where year is encoded in only two digits are years from the 1900's (e.g. 1/5/89 is January 5th, 1989)
# * If the day is missing (e.g. 9/2009), assume it is the first day of the month (e.g. September 1, 2009).
# * If the month is missing (e.g. 2010), assume it is the first of January of that year (e.g. January 1, 2010).
#
# With these rules in mind, find the correct date in each note and return a pandas Series in chronological order of the original Series' indices.
#
# For example if the original series was this:
#
#     0    1999
#     1    2010
#     2    1978
#     3    2015
#     4    1985
#
# Your function should return this:
#
#     0    2
#     1    4
#     2    0
#     3    1
#     4    3
#
# Your score will be calculated using [Kendall's tau](https://en.wikipedia.org/wiki/Kendall_rank_correlation_coefficient), a correlation measure for ordinal data.
#
# *This function should return a Series of length 500 and dtype int.*

# %%
import pandas as pd

doc = []
with open('dates.txt') as file:
    for line in file:
        doc.append(line)

df = pd.Series(doc)
#df.head(10)
#df.str.extractall(r'(?P<month>\d{1,2})[/-](?P<day>\d{1,2})[/-](?P<year>\d{2,4})')
#df.str.extractall(r'(?P<month>(?:\d{2} )?(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*) (?P<day>(?:\d{2}, ))(?P<year>?\d{4})')
#df.str.extractall(r'(?P<month>(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*) (?P<day>(?:\d{2})), ?(?P<year>(\d{4}))')
#a = df.str.extract(r'((?:\d{,2}\s)?(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*(?:-|\.|\s|,)\s?\d{,2}[a-z]*(?:-|,|\s)?\s?\d{2,4})')
##a[a.notnull()]
#b = df.str.extract(r'((?:\d{1,2})(?:(?:\/|-)\d{1,2})(?:(?:\/|-)\d{2,4}))')
#b[b.notnull()]
#c = df.str.extract(r'((?:\d{1,2}(?:-|\/))?\d{4})')
#c[c.notnull()]
#df.str.extractall(r'[^,\d/]\s(?P<year>\d{4})[^\d]')
#df.str.extractall(r'[^\d{1}]\s(?P<month>(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*)(?:[,\.])\s(?P<year>\d{4})')

# %%
def date_sorter():
    
    # Your code here
    from dateutil.parser import parse
    '''
    pattern_one = df.str.extractall(r'(?P<month>\d{1,2})[/-](?P<day>\d{1,2})[/-](?P<year>\d{2,4})')
    pattern_two = df.str.extractall(r'(?P<month>(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*)[\s-](?P<day>(?:\d{1,2}))[\.,]?[\s-](?P<year>\d{4})')
    pattern_three = df.str.extractall(r'(?P<day>(?:\d{1,2}))\s(?P<month>(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*)[,\.]?\s(?P<year>\d{4})')
    pattern_four = df.str.extractall(r'[^\d{1}]\s(?P<month>(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*)(?:[,\.])\s(?P<year>\d{4})')
    #pattern_five =
    pattern_six = df.str.extractall(r'[^\d/-](?P<month>\d{1,2})[/-](?P<year>\d{4})')
    pattern_seven = df.str.extractall(r'[^,\d/]\s(?P<year>\d{4})[^\d]')
    
    p1_list = [i[0] for i in pattern_one.index.tolist()]
    p2_list = [i[0] for i in pattern_two.index.tolist()]
    p3_list = [i[0] for i in pattern_three.index.tolist()]
    p4_list = [i[0] for i in pattern_four.index.tolist()]
    p6_list = [i[0] for i in pattern_six.index.tolist()]
    p7_list = [i[0] for i in pattern_seven.index.tolist()]
    '''
    pattern_one = df.str.extract(r'(?P<month>\d{1,2})[/-](?P<day>\d{1,2})[/-](?P<year>\d{2,4})')
    pattern_one = pattern_one[pattern_one.year.notnull()]
    #print(pattern_one.shape)
    pattern_two = df.str.extract(r'(?P<month>(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*)[\.]?[\s-](?P<day>(?:\d{1,2}))[\.,]?[\s-](?P<year>\d{4})')
    pattern_two = pattern_two[pattern_two.year.notnull()]
    #print(pattern_two.shape)
    pattern_three = df.str.extract(r'(?P<day>(?:\d{1,2}))\s(?P<month>(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*)[,\.]?\s(?P<year>\d{4})')
    pattern_three = pattern_three[pattern_three.year.notnull()]
    #print(pattern_three.shape)
    pattern_four = df.str.extract(r'[^\d{1}]\s(?P<month>(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*)(?:[,\.])\s(?P<year>\d{4})')
    pattern_four = pattern_four[pattern_four.year.notnull()]
    #print(pattern_four.shape)
    #pattern_five =
    pattern_six = df.str.extract(r'[^\d/-](?P<month>\d{1,2})[/-](?P<year>\d{4})')
    pattern_six = pattern_six[pattern_six.year.notnull()]
    #print(pattern_six.shape)
    pattern_seven = df.str.extract(r'[^,\d/]\s(?P<year>\d{4})[^\d]')
    pattern_seven = pattern_seven.dropna()
    #print(pattern_seven.shape)
    
    p1_list = [i for i in pattern_one.index.tolist()]
    #print(len(p1_list))
    p2_list = [i for i in pattern_two.index.tolist()]
    p3_list = [i for i in pattern_three.index.tolist()]
    p4_list = [i for i in pattern_four.index.tolist()]
    p6_list = [i for i in pattern_six.index.tolist()]
    p7_list = [i for i in pattern_seven.index.tolist()]
    
    list3_7=[]

    for i in p3_list:
        if i in p7_list:
            list3_7.append(i)
    
    #print(len(list3_7))
    #print(pattern_seven.shape)
    # clear out duplicate entries 
    #print(pattern_seven.shape)
    #print(list3_7)
    #print(pattern_seven.index.tolist())
    #pattern_seven = pattern_seven.drop(pattern_seven.index[list3_7])
    #pattern_seven = pattern_seven.drop(pattern_seven.index[[0, 1]])
    pattern_seven = pattern_seven.drop(list3_7)
    #print(pattern_seven.index.tolist())
    #print(pattern_seven[127])
    #print(pattern_seven.shape)
    # update p7_list
    #print(len(p7_list))
    #print(p7_list)
    p7_list = [i for i in pattern_seven.index.tolist()]
    #print(len(p7_list))
    #print(p7_list)
    #print(pattern_seven.shape)
    '''
    list3_6=[]
    for i in p6_list:
        if i in p7_list:
            list3_6.append(i)
    print(list3_6)      
    '''
    test_list=[]

    for i in p7_list:
        if i in p3_list:
            test_list.append(i)
            
    #print(test_list)
    #print(pattern_seven.index)
    #print(p7_list)
    
    # drop double items from pattern_7
    combined_indices = pattern_one.index.tolist() + pattern_two.index.tolist() + pattern_three.index.tolist() + pattern_four.index.tolist() + pattern_six.index.tolist() + pattern_seven.index.tolist()
    #print(len(combined_indices))
    combined_indices.sort()
    #print(combined_indices)
    comparison_list = list(range(0, 500))
    missing_indices = []
    for i in comparison_list:
        if i not in combined_indices:
            missing_indices.append(i)
            
    #print(len(missing_indices))
    #print(missing_indices)
    #print(df[321])
    p1 = df.str.extract(r'((?:\d{,2}\s)?(?:Jan|Feb|Mar|Apr|May|Jun|Jul|Aug|Sep|Oct|Nov|Dec)[a-z]*(?:-|\.|\s|,)\s?\d{,2}[a-z]*(?:-|,|\s)?\s?\d{2,4})')
    #print(a[a.notnull()])
    #print(a[175])
    
    p2 = df.str.extract(r'((?:\d{1,2})(?:(?:\/|-)\d{1,2})(?:(?:\/|-)\d{2,4}))')
    #print(b[b.notnull()])
    
    p3 = df.str.extract(r'((?:\d{1,2}(?:-|\/))?\d{4})')
    #print(c[c.notnull()])
    
    regroup = p1.fillna(p2)
    regroup = regroup.fillna(p3)
    # fix some messed up values
    regroup[298] = "January 1993"
    regroup[313] = "December 1978"
    re_df = regroup.reset_index()
    re_df.columns = ['orig_idx', 'raw_str']
    #re_df['dt'] = parse(re_df['raw_str'])
   # re_df['raw_str'].apply(parse)
    #re_df['dt']  = pd.to_datetime(re_df['raw_str'])
    #re_df.loc[re_df['raw_str'] == 'Janaury 1993'] = 'January 1993'
    #re_df.loc[re_df['raw_str'] == 'Janaury 1993'] = 'January 1993'
    re_df['dt'] = pd.to_datetime(re_df['raw_str'], errors='coerce')
    re_df.sort_values('dt', inplace=True)
    re2_df = re_df.reset_index()
    #print(re2_df)
    #print(re2_df['orig_idx'])
    #print(re_df[re_df.dt.isnull()])
    #print(re_df.iloc(298)['raw_str'])
    
    
    return re2_df['orig_idx']# Your answer here

#date_sorter()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:21: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:24: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# /opt/conda/lib/python3.6/site-packages/ipykernel/__main__.py:27: FutureWarning: currently extract(expand=None) means expand=False (return Index/Series/DataFrame) but in a future version of pandas this will be changed to expand=True (return DataFrame)
# ...
